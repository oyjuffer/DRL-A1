# %% [markdown]
# # Assignment 1 - CATCH
#
# Sources: \
# https://github.com/yxu1168/Reinforcement-Learning-DQN-for-ATARI-s-Pong-Game---TensorFlow-2.0-Keras/blob/master/Reinforcement_Learning_CNN_DQN_for_ATARI%E2%80%99s_Pong_Game.ipynb
#
# https://github.com/PacktPublishing/Hands-on-Reinforcement-Learning-with-PyTorch/blob/master/Section%203/3.5%20DQN%20with%20Pong.ipynb

# %% [markdown]
# ## Libraries

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import resize

from collections import deque

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Catch

# %%
class CatchEnv():
    def __init__(self):
        self.size = 21
        self.image = np.zeros((self.size, self.size))
        self.state = []
        self.fps = 4
        self.output_shape = (84, 84)

    def reset_random(self):
        self.image.fill(0)
        self.pos = np.random.randint(2, self.size-2)
        self.vx = np.random.randint(5) - 2
        self.vy = 1
        self.ballx, self.bally = np.random.randint(self.size), 4
        self.image[self.bally, self.ballx] = 1
        self.image[-5, self.pos - 2:self.pos + 3] = np.ones(5)

        return self.step(2)[0]


    def step(self, action):
        def left():
            if self.pos > 3:
                self.pos -= 2
        def right():
            if self.pos < 17:
                self.pos += 2
        def noop():
            pass
        {0: left, 1: right, 2: noop}[action]()

        self.image[self.bally, self.ballx] = 0
        self.ballx += self.vx
        self.bally += self.vy
        if self.ballx > self.size - 1:
            self.ballx -= 2 * (self.ballx - (self.size-1))
            self.vx *= -1
        elif self.ballx < 0:
            self.ballx += 2 * (0 - self.ballx)
            self.vx *= -1
        self.image[self.bally, self.ballx] = 1

        self.image[-5].fill(0)
        self.image[-5, self.pos-2:self.pos+3] = np.ones(5)
    
        terminal = self.bally == self.size - 1 - 4
        reward = int(self.pos - 2 <= self.ballx <= self.pos + 2) if terminal else 0

        [self.state.append(resize(self.image, (84, 84))) for _ in range(self.fps - len(self.state) + 1)]
        self.state = self.state[-self.fps:]

        return np.transpose(self.state, [1, 2, 0]), reward, terminal

    def get_num_actions(self):
        return 3

    def reset(self):
        return self.reset_random()

    def state_shape(self):
        return (self.fps,) + self.output_shape

# %% [markdown]
# ## Experience Replay Buffer

# %%
class ReplayBuffer():
    def __init__(self):
        self.buffer = deque()# queue of trajectories. Newest trajectories are appended to tthe beginning
        self.max_size = 1e6 # maximum number of trajectories to store
    
    def add(self, data):
        if len(self.buffer) == self.max_size:
            self.buffer.pop()
            self.buffer.appendleft(data)
        else:
            self.buffer.appendleft(data)

    def sample(self, batch_size):
        indices = np.random.randint(len(self.buffer), size=batch_size)
        states, actions, rewards, states_next, terminals = [], [], [], [], []

        for i in indices:
            s, a, r, sn, t = self.buffer[i]
            states.append(s)
            actions.append(a)
            rewards.append(r)
            states_next.append(sn)
            terminals.append(t)
            
        return np.array(states), np.array(actions), np.array(rewards), np.array(states_next), np.array(terminals)

# %% [markdown]
# ## Deep Q Network

# %%
input_shape = (84, 84, 4)
num_actions = 3

def DQN_Model():
    model = tf.keras.models.Sequential([
        # tf.keras.layers.Lambda(lambda x: x / 255.0, input_shape=input_shape),
        tf.keras.layers.Conv2D(16, kernel_size = 2, strides = 2, padding="valid", activation='relu', input_shape=input_shape),
        tf.keras.layers.Conv2D(32, kernel_size = 2, strides = 2, padding="valid", activation='relu'),
        # tf.keras.layers.Conv2D(64, kernel_size = 3, strides = 1, padding="valid", activation='relu'),
        tf.keras.layers.Flatten(),
        # tf.keras.layers.Dense(64, activation='relu'),
        # tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(num_actions)
    ])
    
    return model

# %% [markdown]
# ## Agent

# %%
optimizer = keras.optimizers.experimental.RMSprop(learning_rate=0.001)
loss_fn = keras.losses.mean_squared_error # huber

class Agent():
    def __init__(self):
        self.action_size = num_actions
        self.train_net = DQN_Model()
        self.target_net = DQN_Model()
        # self.target_net.set_weights([ii*4 for ii in self.train_net.get_weights()])
        
        # hyperparameters
        self.batch_size = 32
        self.epsilon = 1.0
        self.epsilon_end = 0.1
        self.epsilon_decay = 0.01
        self.gamma = 0.95
        # self.clip_norm = 1.0

    # select an action based on epsilon greedy method
    def action(self, state, evaluate):
        if np.random.rand() < self.epsilon and not evaluate:
            return random.randint(0, 2)
        else:
            return np.argmax(self.train_net(state))

    # decay epsilon
    def decay_epsilon(self):
        if self.epsilon > self.epsilon_end:
            self.epsilon -= self.epsilon_decay

    # train the model
    def train(self, replay_buffer):

        # sample from the experience replay buffer
        states, actions, rewards, states_next, terminals = replay_buffer.sample(self.batch_size)
         
        target_q = rewards + (1 - terminals) * self.gamma * tf.reduce_max(self.target_net(states_next), axis=1) 
        mask = tf.one_hot(actions, self.action_size)

        # GradientTape is a more customizable version of .fit()
        with tf.GradientTape() as tape:
            all_train_q = self.train_net(states)
            train_q = tf.reduce_sum(all_train_q*mask, axis=1, keepdims=True)
            loss = tf.reduce_mean(loss_fn(target_q, train_q))

        gradients = tape.gradient(loss, self.train_net.trainable_variables)
        optimizer.apply_gradients(zip(gradients, self.train_net.trainable_variables))

        return loss


    # update the target network
    def update_target_network(self):
        self.target_net.set_weights(self.train_net.get_weights())

# %% [markdown]
# ## Main Loop

# %%
def run_environment():
    env = CatchEnv()
    agent = Agent()
    replay_buffer = ReplayBuffer()

    # hyperparameters
    episodes = 500
    evaluate = False
    evaluate_point = 10 # number of episodes for training/testing alternatively
    counter_evaluate = evaluate_point
    update_tn_point = 17      # when to update the target model
    counter_update = update_tn_point
    
    # trackers
    reward_tracker = []
    loss_tracker = []

    for episode in range(episodes):

        state = env.reset()
        terminal = False
        
        while not terminal:
            
            # agent takes an action
            action = agent.action(np.reshape(state, (1, 84, 84, 4)), evaluate)

            # generate the next frame based on the agent action
            state_next, reward, terminal = env.step(action)

            # add experience to replay buffer
            replay_buffer.add((state, action, reward, state_next, terminal))

            # update the current state
            state = state_next
            
        # train the agent
        if not evaluate:
            loss = agent.train(replay_buffer)
            loss_tracker.append(loss.numpy())

            
        # update the target network
        counter_update -= 1
        if counter_update == 0:
            counter_update = update_tn_point
            agent.update_target_network()
                
        counter_evaluate -= 1
        if counter_evaluate == 0:
            counter_evaluate = evaluate_point
            evaluate = not evaluate

        # decay epsilon
        agent.decay_epsilon()

        # stats
        reward_tracker.append(reward)
        print("EPISODE: {} --- Rewards: {} --- Loss.avg:{:.5f} --- Avg.score: {} --- Evaluate: {} ".format(episode, 
                                    sum(reward_tracker), round(sum(loss_tracker[-100:])/100.0, 5), round(sum(reward_tracker[-100:])/100, 2), evaluate))

    return np.array(reward_tracker), np.array(loss_tracker)

# %% [markdown]
# # Run

# %%
rewards, loss = run_environment()
# Out:
# EPISODE: 0 --- Rewards: 0 --- Loss.avg:0.00001 --- Avg.score: 0.0 --- Evaluate: False
# EPISODE: 1 --- Rewards: 0 --- Loss.avg:0.00020 --- Avg.score: 0.0 --- Evaluate: False
# EPISODE: 2 --- Rewards: 0 --- Loss.avg:0.00021 --- Avg.score: 0.0 --- Evaluate: False
# EPISODE: 3 --- Rewards: 0 --- Loss.avg:0.00022 --- Avg.score: 0.0 --- Evaluate: False
# EPISODE: 4 --- Rewards: 1 --- Loss.avg:0.00054 --- Avg.score: 0.01 --- Evaluate: False
# EPISODE: 5 --- Rewards: 2 --- Loss.avg:0.00054 --- Avg.score: 0.02 --- Evaluate: False
# EPISODE: 6 --- Rewards: 2 --- Loss.avg:0.00055 --- Avg.score: 0.02 --- Evaluate: False
# EPISODE: 7 --- Rewards: 3 --- Loss.avg:0.00086 --- Avg.score: 0.03 --- Evaluate: False
# EPISODE: 8 --- Rewards: 3 --- Loss.avg:0.00087 --- Avg.score: 0.03 --- Evaluate: False
# EPISODE: 9 --- Rewards: 3 --- Loss.avg:0.00087 --- Avg.score: 0.03 --- Evaluate: True
# EPISODE: 10 --- Rewards: 3 --- Loss.avg:0.00087 --- Avg.score: 0.03 --- Evaluate: True
# EPISODE: 11 --- Rewards: 3 --- Loss.avg:0.00087 --- Avg.score: 0.03 --- Evaluate: True
# EPISODE: 12 --- Rewards: 3 --- Loss.avg:0.00087 --- Avg.score: 0.03 --- Evaluate: True
# EPISODE: 13 --- Rewards: 3 --- Loss.avg:0.00087 --- Avg.score: 0.03 --- Evaluate: True
# EPISODE: 14 --- Rewards: 4 --- Loss.avg:0.00087 --- Avg.score: 0.04 --- Evaluate: True
# EPISODE: 15 --- Rewards: 4 --- Loss.avg:0.00087 --- Avg.score: 0.04 --- Evaluate: True
# EPISODE: 16 --- Rewards: 4 --- Loss.avg:0.00087 --- Avg.score: 0.04 --- Evaluate: True
# EPISODE: 17 --- Rewards: 4 --- Loss.avg:0.00087 --- Avg.score: 0.04 --- Evaluate: True
# EPISODE: 18 --- Rewards: 4 --- Loss.avg:0.00087 --- Avg.score: 0.04 --- Evaluate: True
# EPISODE: 19 --- Rewards: 5 --- Loss.avg:0.00087 --- Avg.score: 0.05 --- Evaluate: False
# EPISODE: 20 --- Rewards: 5 --- Loss.avg:0.00212 --- Avg.score: 0.05 --- Evaluate: False
# EPISODE: 21 --- Rewards: 5 --- Loss.avg:0.00242 --- Avg.score: 0.05 --- Evaluate: False
# EPISODE: 22 --- Rewards: 6 --- Loss.avg:0.00272 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 23 --- Rewards: 6 --- Loss.avg:0.00360 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 24 --- Rewards: 6 --- Loss.avg:0.00366 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 25 --- Rewards: 6 --- Loss.avg:0.00425 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 26 --- Rewards: 6 --- Loss.avg:0.00426 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 27 --- Rewards: 6 --- Loss.avg:0.00427 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 28 --- Rewards: 6 --- Loss.avg:0.00427 --- Avg.score: 0.06 --- Evaluate: False
# EPISODE: 29 --- Rewards: 6 --- Loss.avg:0.00428 --- Avg.score: 0.06 --- Evaluate: True
# EPISODE: 30 --- Rewards: 6 --- Loss.avg:0.00428 --- Avg.score: 0.06 --- Evaluate: True
# EPISODE: 31 --- Rewards: 6 --- Loss.avg:0.00428 --- Avg.score: 0.06 --- Evaluate: True
# EPISODE: 32 --- Rewards: 6 --- Loss.avg:0.00428 --- Avg.score: 0.06 --- Evaluate: True
# EPISODE: 33 --- Rewards: 7 --- Loss.avg:0.00428 --- Avg.score: 0.07 --- Evaluate: True
# EPISODE: 34 --- Rewards: 7 --- Loss.avg:0.00428 --- Avg.score: 0.07 --- Evaluate: True
# EPISODE: 35 --- Rewards: 8 --- Loss.avg:0.00428 --- Avg.score: 0.08 --- Evaluate: True
# EPISODE: 36 --- Rewards: 8 --- Loss.avg:0.00428 --- Avg.score: 0.08 --- Evaluate: True
# EPISODE: 37 --- Rewards: 9 --- Loss.avg:0.00428 --- Avg.score: 0.09 --- Evaluate: True
# EPISODE: 38 --- Rewards: 9 --- Loss.avg:0.00428 --- Avg.score: 0.09 --- Evaluate: True
# EPISODE: 39 --- Rewards: 9 --- Loss.avg:0.00428 --- Avg.score: 0.09 --- Evaluate: False
# EPISODE: 40 --- Rewards: 10 --- Loss.avg:0.00428 --- Avg.score: 0.1 --- Evaluate: False
# EPISODE: 41 --- Rewards: 10 --- Loss.avg:0.00458 --- Avg.score: 0.1 --- Evaluate: False
# EPISODE: 42 --- Rewards: 10 --- Loss.avg:0.00488 --- Avg.score: 0.1 --- Evaluate: False
# EPISODE: 43 --- Rewards: 10 --- Loss.avg:0.00488 --- Avg.score: 0.1 --- Evaluate: False
# EPISODE: 44 --- Rewards: 10 --- Loss.avg:0.00548 --- Avg.score: 0.1 --- Evaluate: False
# EPISODE: 45 --- Rewards: 11 --- Loss.avg:0.00549 --- Avg.score: 0.11 --- Evaluate: False
# EPISODE: 46 --- Rewards: 12 --- Loss.avg:0.00579 --- Avg.score: 0.12 --- Evaluate: False
# EPISODE: 47 --- Rewards: 12 --- Loss.avg:0.00608 --- Avg.score: 0.12 --- Evaluate: False
# EPISODE: 48 --- Rewards: 13 --- Loss.avg:0.00638 --- Avg.score: 0.13 --- Evaluate: False
# EPISODE: 49 --- Rewards: 13 --- Loss.avg:0.00724 --- Avg.score: 0.13 --- Evaluate: True
# EPISODE: 50 --- Rewards: 13 --- Loss.avg:0.00724 --- Avg.score: 0.13 --- Evaluate: True
# EPISODE: 51 --- Rewards: 13 --- Loss.avg:0.00724 --- Avg.score: 0.13 --- Evaluate: True
# EPISODE: 52 --- Rewards: 13 --- Loss.avg:0.00724 --- Avg.score: 0.13 --- Evaluate: True
# EPISODE: 53 --- Rewards: 14 --- Loss.avg:0.00724 --- Avg.score: 0.14 --- Evaluate: True
# EPISODE: 54 --- Rewards: 14 --- Loss.avg:0.00724 --- Avg.score: 0.14 --- Evaluate: True
# EPISODE: 55 --- Rewards: 14 --- Loss.avg:0.00724 --- Avg.score: 0.14 --- Evaluate: True
# EPISODE: 56 --- Rewards: 14 --- Loss.avg:0.00724 --- Avg.score: 0.14 --- Evaluate: True
# EPISODE: 57 --- Rewards: 15 --- Loss.avg:0.00724 --- Avg.score: 0.15 --- Evaluate: True
# EPISODE: 58 --- Rewards: 15 --- Loss.avg:0.00724 --- Avg.score: 0.15 --- Evaluate: True
# EPISODE: 59 --- Rewards: 15 --- Loss.avg:0.00724 --- Avg.score: 0.15 --- Evaluate: False
# EPISODE: 60 --- Rewards: 15 --- Loss.avg:0.00726 --- Avg.score: 0.15 --- Evaluate: False
# EPISODE: 61 --- Rewards: 15 --- Loss.avg:0.00754 --- Avg.score: 0.15 --- Evaluate: False
# EPISODE: 62 --- Rewards: 16 --- Loss.avg:0.00756 --- Avg.score: 0.16 --- Evaluate: False
# EPISODE: 63 --- Rewards: 17 --- Loss.avg:0.00757 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 64 --- Rewards: 17 --- Loss.avg:0.00836 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 65 --- Rewards: 18 --- Loss.avg:0.00844 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 66 --- Rewards: 18 --- Loss.avg:0.00871 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 67 --- Rewards: 18 --- Loss.avg:0.00872 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 68 --- Rewards: 18 --- Loss.avg:0.00898 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 69 --- Rewards: 18 --- Loss.avg:0.00924 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 70 --- Rewards: 18 --- Loss.avg:0.00924 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 71 --- Rewards: 18 --- Loss.avg:0.00924 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 72 --- Rewards: 18 --- Loss.avg:0.00924 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 73 --- Rewards: 19 --- Loss.avg:0.00924 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 74 --- Rewards: 19 --- Loss.avg:0.00924 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 75 --- Rewards: 20 --- Loss.avg:0.00924 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 76 --- Rewards: 20 --- Loss.avg:0.00924 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 77 --- Rewards: 21 --- Loss.avg:0.00924 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 78 --- Rewards: 21 --- Loss.avg:0.00924 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 79 --- Rewards: 21 --- Loss.avg:0.00924 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 80 --- Rewards: 21 --- Loss.avg:0.00925 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 81 --- Rewards: 21 --- Loss.avg:0.00952 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 82 --- Rewards: 21 --- Loss.avg:0.00978 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 83 --- Rewards: 21 --- Loss.avg:0.01005 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 84 --- Rewards: 21 --- Loss.avg:0.01031 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 85 --- Rewards: 21 --- Loss.avg:0.01057 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 86 --- Rewards: 21 --- Loss.avg:0.01080 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 87 --- Rewards: 21 --- Loss.avg:0.01083 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 88 --- Rewards: 21 --- Loss.avg:0.01084 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 89 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 90 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 91 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 92 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 93 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 94 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 95 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 96 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 97 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 98 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 99 --- Rewards: 21 --- Loss.avg:0.01085 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 100 --- Rewards: 22 --- Loss.avg:0.01110 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 101 --- Rewards: 22 --- Loss.avg:0.01113 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 102 --- Rewards: 22 --- Loss.avg:0.01114 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 103 --- Rewards: 23 --- Loss.avg:0.01166 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 104 --- Rewards: 23 --- Loss.avg:0.01169 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 105 --- Rewards: 23 --- Loss.avg:0.01170 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 106 --- Rewards: 24 --- Loss.avg:0.01170 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 107 --- Rewards: 25 --- Loss.avg:0.01197 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 108 --- Rewards: 25 --- Loss.avg:0.01198 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 109 --- Rewards: 26 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 110 --- Rewards: 26 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 111 --- Rewards: 26 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 112 --- Rewards: 26 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 113 --- Rewards: 26 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 114 --- Rewards: 27 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 115 --- Rewards: 27 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 116 --- Rewards: 27 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 117 --- Rewards: 27 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 118 --- Rewards: 27 --- Loss.avg:0.01224 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 119 --- Rewards: 27 --- Loss.avg:0.01224 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 120 --- Rewards: 28 --- Loss.avg:0.01249 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 121 --- Rewards: 28 --- Loss.avg:0.01297 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 122 --- Rewards: 29 --- Loss.avg:0.01324 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 123 --- Rewards: 29 --- Loss.avg:0.01326 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 124 --- Rewards: 29 --- Loss.avg:0.01326 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 125 --- Rewards: 29 --- Loss.avg:0.01352 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 126 --- Rewards: 29 --- Loss.avg:0.01378 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 127 --- Rewards: 29 --- Loss.avg:0.01379 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 128 --- Rewards: 29 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 129 --- Rewards: 29 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 130 --- Rewards: 29 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 131 --- Rewards: 29 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 132 --- Rewards: 29 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 133 --- Rewards: 30 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 134 --- Rewards: 30 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 135 --- Rewards: 31 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 136 --- Rewards: 31 --- Loss.avg:0.01380 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 137 --- Rewards: 31 --- Loss.avg:0.01380 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 138 --- Rewards: 31 --- Loss.avg:0.01380 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 139 --- Rewards: 31 --- Loss.avg:0.01380 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 140 --- Rewards: 31 --- Loss.avg:0.01381 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 141 --- Rewards: 31 --- Loss.avg:0.01460 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 142 --- Rewards: 32 --- Loss.avg:0.01486 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 143 --- Rewards: 33 --- Loss.avg:0.01487 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 144 --- Rewards: 33 --- Loss.avg:0.01512 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 145 --- Rewards: 33 --- Loss.avg:0.01514 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 146 --- Rewards: 34 --- Loss.avg:0.01541 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 147 --- Rewards: 34 --- Loss.avg:0.01591 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 148 --- Rewards: 34 --- Loss.avg:0.01618 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 149 --- Rewards: 34 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 150 --- Rewards: 34 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 151 --- Rewards: 34 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 152 --- Rewards: 34 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 153 --- Rewards: 34 --- Loss.avg:0.01619 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 154 --- Rewards: 34 --- Loss.avg:0.01619 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 155 --- Rewards: 35 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 156 --- Rewards: 35 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 157 --- Rewards: 36 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 158 --- Rewards: 36 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 159 --- Rewards: 36 --- Loss.avg:0.01619 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 160 --- Rewards: 36 --- Loss.avg:0.01645 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 161 --- Rewards: 36 --- Loss.avg:0.01646 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 162 --- Rewards: 37 --- Loss.avg:0.01673 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 163 --- Rewards: 37 --- Loss.avg:0.01674 --- Avg.score: 0.2 --- Evaluate: False
# EPISODE: 164 --- Rewards: 37 --- Loss.avg:0.01725 --- Avg.score: 0.2 --- Evaluate: False
# EPISODE: 165 --- Rewards: 37 --- Loss.avg:0.01751 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 166 --- Rewards: 37 --- Loss.avg:0.01776 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 167 --- Rewards: 37 --- Loss.avg:0.01825 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 168 --- Rewards: 37 --- Loss.avg:0.01830 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 169 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 170 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 171 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 172 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 173 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 174 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 175 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.17 --- Evaluate: True
# EPISODE: 176 --- Rewards: 37 --- Loss.avg:0.01831 --- Avg.score: 0.17 --- Evaluate: True
# EPISODE: 177 --- Rewards: 38 --- Loss.avg:0.01831 --- Avg.score: 0.17 --- Evaluate: True
# EPISODE: 178 --- Rewards: 38 --- Loss.avg:0.01831 --- Avg.score: 0.17 --- Evaluate: True
# EPISODE: 179 --- Rewards: 38 --- Loss.avg:0.01831 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 180 --- Rewards: 38 --- Loss.avg:0.01832 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 181 --- Rewards: 38 --- Loss.avg:0.01833 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 182 --- Rewards: 38 --- Loss.avg:0.01859 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 183 --- Rewards: 38 --- Loss.avg:0.01910 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 184 --- Rewards: 38 --- Loss.avg:0.01913 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 185 --- Rewards: 39 --- Loss.avg:0.01940 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 186 --- Rewards: 40 --- Loss.avg:0.01941 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 187 --- Rewards: 40 --- Loss.avg:0.01941 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 188 --- Rewards: 40 --- Loss.avg:0.02019 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 189 --- Rewards: 41 --- Loss.avg:0.02070 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 190 --- Rewards: 41 --- Loss.avg:0.02070 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 191 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 192 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 193 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 194 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 195 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 196 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 197 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 198 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 199 --- Rewards: 42 --- Loss.avg:0.02070 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 200 --- Rewards: 43 --- Loss.avg:0.02072 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 201 --- Rewards: 44 --- Loss.avg:0.02079 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 202 --- Rewards: 45 --- Loss.avg:0.02129 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 203 --- Rewards: 46 --- Loss.avg:0.02153 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 204 --- Rewards: 46 --- Loss.avg:0.02146 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 205 --- Rewards: 46 --- Loss.avg:0.02172 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 206 --- Rewards: 47 --- Loss.avg:0.02219 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 207 --- Rewards: 47 --- Loss.avg:0.02215 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 208 --- Rewards: 47 --- Loss.avg:0.02239 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 209 --- Rewards: 47 --- Loss.avg:0.02240 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 210 --- Rewards: 48 --- Loss.avg:0.02240 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 211 --- Rewards: 48 --- Loss.avg:0.02240 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 212 --- Rewards: 48 --- Loss.avg:0.02240 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 213 --- Rewards: 48 --- Loss.avg:0.02240 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 214 --- Rewards: 49 --- Loss.avg:0.02240 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 215 --- Rewards: 49 --- Loss.avg:0.02240 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 216 --- Rewards: 50 --- Loss.avg:0.02240 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 217 --- Rewards: 50 --- Loss.avg:0.02240 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 218 --- Rewards: 51 --- Loss.avg:0.02240 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 219 --- Rewards: 51 --- Loss.avg:0.02240 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 220 --- Rewards: 51 --- Loss.avg:0.02116 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 221 --- Rewards: 51 --- Loss.avg:0.02136 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 222 --- Rewards: 51 --- Loss.avg:0.02108 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 223 --- Rewards: 51 --- Loss.avg:0.02045 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 224 --- Rewards: 51 --- Loss.avg:0.02087 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 225 --- Rewards: 52 --- Loss.avg:0.02031 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 226 --- Rewards: 53 --- Loss.avg:0.02057 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 227 --- Rewards: 53 --- Loss.avg:0.02081 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 228 --- Rewards: 53 --- Loss.avg:0.02082 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 229 --- Rewards: 53 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 230 --- Rewards: 53 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 231 --- Rewards: 53 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 232 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 233 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 234 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 235 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 236 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 237 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 238 --- Rewards: 54 --- Loss.avg:0.02108 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 239 --- Rewards: 55 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 240 --- Rewards: 55 --- Loss.avg:0.02108 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 241 --- Rewards: 55 --- Loss.avg:0.02078 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 242 --- Rewards: 55 --- Loss.avg:0.02074 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 243 --- Rewards: 55 --- Loss.avg:0.02098 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 244 --- Rewards: 56 --- Loss.avg:0.02042 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 245 --- Rewards: 56 --- Loss.avg:0.02043 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 246 --- Rewards: 56 --- Loss.avg:0.02039 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 247 --- Rewards: 56 --- Loss.avg:0.02034 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 248 --- Rewards: 56 --- Loss.avg:0.02005 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 249 --- Rewards: 57 --- Loss.avg:0.01943 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 250 --- Rewards: 57 --- Loss.avg:0.01943 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 251 --- Rewards: 58 --- Loss.avg:0.01943 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 252 --- Rewards: 58 --- Loss.avg:0.01943 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 253 --- Rewards: 58 --- Loss.avg:0.01943 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 254 --- Rewards: 58 --- Loss.avg:0.01943 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 255 --- Rewards: 58 --- Loss.avg:0.01943 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 256 --- Rewards: 58 --- Loss.avg:0.01943 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 257 --- Rewards: 59 --- Loss.avg:0.01943 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 258 --- Rewards: 60 --- Loss.avg:0.01943 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 259 --- Rewards: 60 --- Loss.avg:0.01943 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 260 --- Rewards: 61 --- Loss.avg:0.01943 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 261 --- Rewards: 62 --- Loss.avg:0.01916 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 262 --- Rewards: 62 --- Loss.avg:0.01964 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 263 --- Rewards: 62 --- Loss.avg:0.01966 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 264 --- Rewards: 62 --- Loss.avg:0.01936 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 265 --- Rewards: 62 --- Loss.avg:0.01952 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 266 --- Rewards: 62 --- Loss.avg:0.01928 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 267 --- Rewards: 62 --- Loss.avg:0.01927 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 268 --- Rewards: 62 --- Loss.avg:0.01924 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 269 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 270 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 271 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 272 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 273 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 274 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 275 --- Rewards: 63 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 276 --- Rewards: 64 --- Loss.avg:0.01922 --- Avg.score: 0.27 --- Evaluate: True
# EPISODE: 277 --- Rewards: 64 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 278 --- Rewards: 64 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 279 --- Rewards: 64 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 280 --- Rewards: 64 --- Loss.avg:0.01945 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 281 --- Rewards: 64 --- Loss.avg:0.01922 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 282 --- Rewards: 64 --- Loss.avg:0.01898 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 283 --- Rewards: 65 --- Loss.avg:0.01896 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 284 --- Rewards: 65 --- Loss.avg:0.01896 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 285 --- Rewards: 65 --- Loss.avg:0.01894 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 286 --- Rewards: 65 --- Loss.avg:0.01874 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 287 --- Rewards: 65 --- Loss.avg:0.01918 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 288 --- Rewards: 65 --- Loss.avg:0.01941 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 289 --- Rewards: 65 --- Loss.avg:0.01967 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 290 --- Rewards: 65 --- Loss.avg:0.01967 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 291 --- Rewards: 65 --- Loss.avg:0.01967 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 292 --- Rewards: 65 --- Loss.avg:0.01967 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 293 --- Rewards: 65 --- Loss.avg:0.01967 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 294 --- Rewards: 65 --- Loss.avg:0.01967 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 295 --- Rewards: 66 --- Loss.avg:0.01967 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 296 --- Rewards: 67 --- Loss.avg:0.01967 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 297 --- Rewards: 67 --- Loss.avg:0.01967 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 298 --- Rewards: 68 --- Loss.avg:0.01967 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 299 --- Rewards: 69 --- Loss.avg:0.01967 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 300 --- Rewards: 69 --- Loss.avg:0.01943 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 301 --- Rewards: 70 --- Loss.avg:0.01964 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 302 --- Rewards: 71 --- Loss.avg:0.01988 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 303 --- Rewards: 71 --- Loss.avg:0.01937 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 304 --- Rewards: 71 --- Loss.avg:0.01937 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 305 --- Rewards: 71 --- Loss.avg:0.01960 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 306 --- Rewards: 71 --- Loss.avg:0.01961 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 307 --- Rewards: 71 --- Loss.avg:0.01937 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 308 --- Rewards: 71 --- Loss.avg:0.01961 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 309 --- Rewards: 71 --- Loss.avg:0.01935 --- Avg.score: 0.24 --- Evaluate: True
# EPISODE: 310 --- Rewards: 71 --- Loss.avg:0.01935 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 311 --- Rewards: 71 --- Loss.avg:0.01935 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 312 --- Rewards: 71 --- Loss.avg:0.01935 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 313 --- Rewards: 71 --- Loss.avg:0.01935 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 314 --- Rewards: 71 --- Loss.avg:0.01935 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 315 --- Rewards: 72 --- Loss.avg:0.01935 --- Avg.score: 0.23 --- Evaluate: True
# EPISODE: 316 --- Rewards: 72 --- Loss.avg:0.01935 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 317 --- Rewards: 72 --- Loss.avg:0.01935 --- Avg.score: 0.22 --- Evaluate: True
# EPISODE: 318 --- Rewards: 72 --- Loss.avg:0.01935 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 319 --- Rewards: 72 --- Loss.avg:0.01935 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 320 --- Rewards: 72 --- Loss.avg:0.01934 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 321 --- Rewards: 72 --- Loss.avg:0.01889 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 322 --- Rewards: 72 --- Loss.avg:0.01864 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 323 --- Rewards: 72 --- Loss.avg:0.01864 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 324 --- Rewards: 72 --- Loss.avg:0.01866 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 325 --- Rewards: 72 --- Loss.avg:0.01863 --- Avg.score: 0.2 --- Evaluate: False
# EPISODE: 326 --- Rewards: 72 --- Loss.avg:0.01840 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 327 --- Rewards: 73 --- Loss.avg:0.01865 --- Avg.score: 0.2 --- Evaluate: False
# EPISODE: 328 --- Rewards: 73 --- Loss.avg:0.01866 --- Avg.score: 0.2 --- Evaluate: False
# EPISODE: 329 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 330 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 331 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 332 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 333 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 334 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 335 --- Rewards: 73 --- Loss.avg:0.01891 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 336 --- Rewards: 74 --- Loss.avg:0.01891 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 337 --- Rewards: 74 --- Loss.avg:0.01891 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 338 --- Rewards: 74 --- Loss.avg:0.01891 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 339 --- Rewards: 74 --- Loss.avg:0.01891 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 340 --- Rewards: 74 --- Loss.avg:0.01913 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 341 --- Rewards: 74 --- Loss.avg:0.01880 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 342 --- Rewards: 74 --- Loss.avg:0.01878 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 343 --- Rewards: 74 --- Loss.avg:0.01880 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 344 --- Rewards: 75 --- Loss.avg:0.01904 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 345 --- Rewards: 75 --- Loss.avg:0.01925 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 346 --- Rewards: 76 --- Loss.avg:0.01924 --- Avg.score: 0.2 --- Evaluate: False
# EPISODE: 347 --- Rewards: 77 --- Loss.avg:0.01920 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 348 --- Rewards: 77 --- Loss.avg:0.01898 --- Avg.score: 0.21 --- Evaluate: False
# EPISODE: 349 --- Rewards: 77 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 350 --- Rewards: 77 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 351 --- Rewards: 77 --- Loss.avg:0.01901 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 352 --- Rewards: 78 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 353 --- Rewards: 78 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 354 --- Rewards: 78 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 355 --- Rewards: 78 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 356 --- Rewards: 78 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 357 --- Rewards: 79 --- Loss.avg:0.01901 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 358 --- Rewards: 79 --- Loss.avg:0.01901 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 359 --- Rewards: 79 --- Loss.avg:0.01901 --- Avg.score: 0.19 --- Evaluate: False
# EPISODE: 360 --- Rewards: 79 --- Loss.avg:0.01901 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 361 --- Rewards: 79 --- Loss.avg:0.01947 --- Avg.score: 0.17 --- Evaluate: False
# EPISODE: 362 --- Rewards: 80 --- Loss.avg:0.01925 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 363 --- Rewards: 80 --- Loss.avg:0.01926 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 364 --- Rewards: 80 --- Loss.avg:0.01876 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 365 --- Rewards: 80 --- Loss.avg:0.01851 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 366 --- Rewards: 80 --- Loss.avg:0.01827 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 367 --- Rewards: 80 --- Loss.avg:0.01803 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 368 --- Rewards: 80 --- Loss.avg:0.01799 --- Avg.score: 0.18 --- Evaluate: False
# EPISODE: 369 --- Rewards: 80 --- Loss.avg:0.01872 --- Avg.score: 0.17 --- Evaluate: True
# EPISODE: 370 --- Rewards: 81 --- Loss.avg:0.01872 --- Avg.score: 0.18 --- Evaluate: True
# EPISODE: 371 --- Rewards: 82 --- Loss.avg:0.01872 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 372 --- Rewards: 82 --- Loss.avg:0.01872 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 373 --- Rewards: 82 --- Loss.avg:0.01872 --- Avg.score: 0.19 --- Evaluate: True
# EPISODE: 374 --- Rewards: 83 --- Loss.avg:0.01872 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 375 --- Rewards: 83 --- Loss.avg:0.01872 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 376 --- Rewards: 84 --- Loss.avg:0.01872 --- Avg.score: 0.2 --- Evaluate: True
# EPISODE: 377 --- Rewards: 85 --- Loss.avg:0.01872 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 378 --- Rewards: 85 --- Loss.avg:0.01872 --- Avg.score: 0.21 --- Evaluate: True
# EPISODE: 379 --- Rewards: 86 --- Loss.avg:0.01872 --- Avg.score: 0.22 --- Evaluate: False
# EPISODE: 380 --- Rewards: 87 --- Loss.avg:0.01873 --- Avg.score: 0.23 --- Evaluate: False
# EPISODE: 381 --- Rewards: 88 --- Loss.avg:0.01898 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 382 --- Rewards: 89 --- Loss.avg:0.01873 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 383 --- Rewards: 89 --- Loss.avg:0.01823 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 384 --- Rewards: 89 --- Loss.avg:0.01821 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 385 --- Rewards: 90 --- Loss.avg:0.01794 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 386 --- Rewards: 90 --- Loss.avg:0.01795 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 387 --- Rewards: 90 --- Loss.avg:0.01795 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 388 --- Rewards: 90 --- Loss.avg:0.01719 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 389 --- Rewards: 90 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 390 --- Rewards: 90 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 391 --- Rewards: 90 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 392 --- Rewards: 90 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 393 --- Rewards: 90 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 394 --- Rewards: 91 --- Loss.avg:0.01694 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 395 --- Rewards: 92 --- Loss.avg:0.01694 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 396 --- Rewards: 92 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 397 --- Rewards: 93 --- Loss.avg:0.01694 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 398 --- Rewards: 93 --- Loss.avg:0.01694 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 399 --- Rewards: 93 --- Loss.avg:0.01694 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 400 --- Rewards: 94 --- Loss.avg:0.01695 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 401 --- Rewards: 95 --- Loss.avg:0.01717 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 402 --- Rewards: 95 --- Loss.avg:0.01713 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 403 --- Rewards: 95 --- Loss.avg:0.01732 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 404 --- Rewards: 95 --- Loss.avg:0.01711 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 405 --- Rewards: 95 --- Loss.avg:0.01688 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 406 --- Rewards: 95 --- Loss.avg:0.01642 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 407 --- Rewards: 95 --- Loss.avg:0.01640 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 408 --- Rewards: 95 --- Loss.avg:0.01639 --- Avg.score: 0.24 --- Evaluate: False
# EPISODE: 409 --- Rewards: 96 --- Loss.avg:0.01686 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 410 --- Rewards: 96 --- Loss.avg:0.01686 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 411 --- Rewards: 96 --- Loss.avg:0.01686 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 412 --- Rewards: 96 --- Loss.avg:0.01686 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 413 --- Rewards: 97 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 414 --- Rewards: 97 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 415 --- Rewards: 97 --- Loss.avg:0.01686 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 416 --- Rewards: 98 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 417 --- Rewards: 98 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 418 --- Rewards: 98 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 419 --- Rewards: 98 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 420 --- Rewards: 98 --- Loss.avg:0.01686 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 421 --- Rewards: 98 --- Loss.avg:0.01639 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 422 --- Rewards: 98 --- Loss.avg:0.01638 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 423 --- Rewards: 98 --- Loss.avg:0.01615 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 424 --- Rewards: 98 --- Loss.avg:0.01592 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 425 --- Rewards: 98 --- Loss.avg:0.01613 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 426 --- Rewards: 98 --- Loss.avg:0.01588 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 427 --- Rewards: 98 --- Loss.avg:0.01588 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 428 --- Rewards: 98 --- Loss.avg:0.01589 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 429 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 430 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 431 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 432 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 433 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 434 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 435 --- Rewards: 98 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 436 --- Rewards: 99 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 437 --- Rewards: 99 --- Loss.avg:0.01564 --- Avg.score: 0.25 --- Evaluate: True
# EPISODE: 438 --- Rewards: 100 --- Loss.avg:0.01564 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 439 --- Rewards: 100 --- Loss.avg:0.01564 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 440 --- Rewards: 101 --- Loss.avg:0.01589 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 441 --- Rewards: 101 --- Loss.avg:0.01591 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 442 --- Rewards: 101 --- Loss.avg:0.01567 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 443 --- Rewards: 101 --- Loss.avg:0.01543 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 444 --- Rewards: 102 --- Loss.avg:0.01542 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 445 --- Rewards: 102 --- Loss.avg:0.01542 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 446 --- Rewards: 102 --- Loss.avg:0.01517 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 447 --- Rewards: 103 --- Loss.avg:0.01495 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 448 --- Rewards: 104 --- Loss.avg:0.01520 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 449 --- Rewards: 105 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 450 --- Rewards: 105 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 451 --- Rewards: 105 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 452 --- Rewards: 106 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 453 --- Rewards: 106 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 454 --- Rewards: 106 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 455 --- Rewards: 107 --- Loss.avg:0.01520 --- Avg.score: 0.29 --- Evaluate: True
# EPISODE: 456 --- Rewards: 107 --- Loss.avg:0.01520 --- Avg.score: 0.29 --- Evaluate: True
# EPISODE: 457 --- Rewards: 107 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 458 --- Rewards: 107 --- Loss.avg:0.01520 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 459 --- Rewards: 108 --- Loss.avg:0.01520 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 460 --- Rewards: 108 --- Loss.avg:0.01519 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 461 --- Rewards: 108 --- Loss.avg:0.01518 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 462 --- Rewards: 108 --- Loss.avg:0.01493 --- Avg.score: 0.28 --- Evaluate: False
# EPISODE: 463 --- Rewards: 109 --- Loss.avg:0.01491 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 464 --- Rewards: 109 --- Loss.avg:0.01443 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 465 --- Rewards: 109 --- Loss.avg:0.01444 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 466 --- Rewards: 110 --- Loss.avg:0.01508 --- Avg.score: 0.3 --- Evaluate: False
# EPISODE: 467 --- Rewards: 110 --- Loss.avg:0.01531 --- Avg.score: 0.3 --- Evaluate: False
# EPISODE: 468 --- Rewards: 110 --- Loss.avg:0.01509 --- Avg.score: 0.3 --- Evaluate: False
# EPISODE: 469 --- Rewards: 111 --- Loss.avg:0.01507 --- Avg.score: 0.31 --- Evaluate: True
# EPISODE: 470 --- Rewards: 112 --- Loss.avg:0.01507 --- Avg.score: 0.31 --- Evaluate: True
# EPISODE: 471 --- Rewards: 112 --- Loss.avg:0.01507 --- Avg.score: 0.3 --- Evaluate: True
# EPISODE: 472 --- Rewards: 112 --- Loss.avg:0.01507 --- Avg.score: 0.3 --- Evaluate: True
# EPISODE: 473 --- Rewards: 113 --- Loss.avg:0.01507 --- Avg.score: 0.31 --- Evaluate: True
# EPISODE: 474 --- Rewards: 113 --- Loss.avg:0.01507 --- Avg.score: 0.3 --- Evaluate: True
# EPISODE: 475 --- Rewards: 113 --- Loss.avg:0.01507 --- Avg.score: 0.3 --- Evaluate: True
# EPISODE: 476 --- Rewards: 114 --- Loss.avg:0.01507 --- Avg.score: 0.3 --- Evaluate: True
# EPISODE: 477 --- Rewards: 114 --- Loss.avg:0.01507 --- Avg.score: 0.29 --- Evaluate: True
# EPISODE: 478 --- Rewards: 114 --- Loss.avg:0.01507 --- Avg.score: 0.29 --- Evaluate: True
# EPISODE: 479 --- Rewards: 115 --- Loss.avg:0.01507 --- Avg.score: 0.29 --- Evaluate: False
# EPISODE: 480 --- Rewards: 115 --- Loss.avg:0.01487 --- Avg.score: 0.28 --- Evaluate: False
# EPISODE: 481 --- Rewards: 115 --- Loss.avg:0.01552 --- Avg.score: 0.27 --- Evaluate: False
# EPISODE: 482 --- Rewards: 115 --- Loss.avg:0.01554 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 483 --- Rewards: 115 --- Loss.avg:0.01553 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 484 --- Rewards: 115 --- Loss.avg:0.01550 --- Avg.score: 0.26 --- Evaluate: False
# EPISODE: 485 --- Rewards: 115 --- Loss.avg:0.01530 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 486 --- Rewards: 115 --- Loss.avg:0.01526 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 487 --- Rewards: 115 --- Loss.avg:0.01503 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 488 --- Rewards: 115 --- Loss.avg:0.01505 --- Avg.score: 0.25 --- Evaluate: False
# EPISODE: 489 --- Rewards: 116 --- Loss.avg:0.01479 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 490 --- Rewards: 116 --- Loss.avg:0.01479 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 491 --- Rewards: 116 --- Loss.avg:0.01479 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 492 --- Rewards: 117 --- Loss.avg:0.01479 --- Avg.score: 0.27 --- Evaluate: True
# EPISODE: 493 --- Rewards: 118 --- Loss.avg:0.01479 --- Avg.score: 0.28 --- Evaluate: True
# EPISODE: 494 --- Rewards: 118 --- Loss.avg:0.01479 --- Avg.score: 0.27 --- Evaluate: True
# EPISODE: 495 --- Rewards: 119 --- Loss.avg:0.01479 --- Avg.score: 0.27 --- Evaluate: True
# EPISODE: 496 --- Rewards: 119 --- Loss.avg:0.01479 --- Avg.score: 0.27 --- Evaluate: True
# EPISODE: 497 --- Rewards: 119 --- Loss.avg:0.01479 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 498 --- Rewards: 119 --- Loss.avg:0.01479 --- Avg.score: 0.26 --- Evaluate: True
# EPISODE: 499 --- Rewards: 119 --- Loss.avg:0.01479 --- Avg.score: 0.26 --- Evaluate: False

# %%
# average reward across 10 episodes
num_episodes = 10
num_samples = rewards.size
num_batches = rewards.size // 10
reward_reshaped = rewards[:num_batches*num_episodes].reshape(num_batches, num_episodes)
average_reward = np.mean(reward_reshaped, axis=1)
plt.figure(figsize=(12,6))
plt.plot(average_reward)
plt.xlabel(f"average of {num_episodes} episodes")
plt.ylabel("reward")
plt.ylim(0, 1)
plt.show()


# average loss across 100 iterations
num_iterations = 100
num_samples = loss.size
num_batches = num_samples // num_iterations
loss_episode_reshaped = loss[:num_batches*num_iterations].reshape(num_batches, num_iterations)
average_loss = np.mean(loss_episode_reshaped, axis=1)
plt.figure(figsize=(12,6))
plt.plot(average_loss)
plt.xlabel(f"average of {num_iterations} iterations")
plt.ylabel("loss")
plt.show()
